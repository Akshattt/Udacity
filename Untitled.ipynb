# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
# %matplotlib notebook
image = mpimg.imread('C:/Users/Akshat/Downloads/example_grid1.jpg')
plt.imshow(image)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
